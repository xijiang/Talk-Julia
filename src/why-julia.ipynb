# %% [markdown]
# # Julia's key features
#
# - 1.3M threads, 1.54 petaflops
#   - 4th language after C, C++, and Fortran to reach P-flops
# - *runs like C, but reads like Python.*
# - a modern programming language which borrows many good features from other languages.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - Two language problem
#
# | Package | Functionality | GitHub URL | Language (%) |
# | --- | --- | --- | --- |
# | data.table | Data frame package for R | Rdatatable/data.table | C (36.3), R(62.4) |
# | randomForest | Random forest algorithm for R | cran/randomForest | C (50.3), R (39.9) |
# | PyTorch | Machine learning library for Python | pytorch/pytorch | C++ (52.6), Python (36.6) |

# %% [markdown]
# | Package | Functionality | GitHub URL | Languages % |
# | --- | --- | --- | --- |
# | DataFrames.jl | Data frame | JuliaData/DataFrames.jl | Julia 100 |
# | DecisionTree.jl | Random forest library | bensadeghi/DecisionTree.jl | Julia 100 |
# | Flux.jl | Machine learning | FluxML/Flux.jl | Julia 100 |

# %% [markdown]
# ## For data scientists
#
# ### A compiled language
# ```julia
# using BenchmarkTools
# function mysum(n)
#     s = 0
#     for i in 1:n
#         s += i
#     end
#     s
# end
# @btime mysum(1_000_000_000)
# # -> 1.6ns
# ```

# %% [markdown]
# ### Interactive workflows
#
# - REPL, Jupyter notebooks, Pluto.jl
#   - blending compilation and execution phases.
# - Dynamically typed
# ```julia
# x = 1   # x is an Int64
# x = 1.0 # x is a Float64, now
# # The variable is only bonded to a value, which determines type
# ```

# %% [markdown]
# ### Reusable
# - Multiple dispatch
# - Arbitrary data
#
# ### Built-in state-of-the-art package manager
#
# ### Integrate existing codes
# - native support to call C and Fortran
# - call C++, Java, MATLAB, Python and R codes with packages

# %% [markdown]
# ## Julia draw-backs
#
# - TTFP
# - Large executable file for machine without Julia
# - Still young
